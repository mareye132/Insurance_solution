# %%
# Import necessary modules and functions
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# Add the correct path to the scripts directory
sys.path.append('C:/Users/user/Desktop/Github/Insurance_solution/Scripts')

# Import the class from the script file
from Insurance_EDA import Insurance_analysis

# Initialize the Insurance_analysis class with your dataset (using | delimiter)
eda = Insurance_analysis('C:/Users/user/Desktop/Github/Insurance_solution/data/MachineLearningRating_v3.txt', delimiter='|')

# Data Summary
print("Data Summary:")
display(eda.data_summary())

# Data Structure
print("\nData Structure:")
display(eda.data_structure())

# Check for missing values
print("\nMissing Values:")
display(eda.check_missing_values())

# Variance for 'TotalPremium'
print("\nVariance of 'TotalPremium':", eda.get_variance('TotalPremium'))

# Standard deviation for 'TotalClaims'
print("Standard Deviation of 'TotalClaims':", eda.get_std_deviation('TotalClaims'))

# Histogram for 'TotalPremium'
print("\nHistogram for 'TotalPremium':")
eda.plot_histogram('TotalPremium')

# Print column names to verify correct column names
print("\nColumn Names:")
print(eda.df.columns)

# Update the bar chart for the correct column name (e.g., 'CoverType')
# Ensure 'CoverType' is the correct column name as per your dataset
# You might need to replace 'CoverType' with the actual column name in your dataset
print("\nBar Chart for 'CoverType':")
eda.plot_bar_chart('CoverType')

# Scatter plot for 'TotalPremium' vs 'TotalClaims'
print("\nScatter Plot for 'TotalPremium' vs 'TotalClaims':")
eda.scatter_plot('TotalPremium', 'TotalClaims')

# Correlation matrix
print("\nCorrelation Matrix:")
eda.correlation_matrix()

# Compare geographical trends (update column names as needed)
print("\nGeographical Trend Comparison (PostalCode vs TotalPremium):")
eda.geographical_trend_comparison('PostalCode', 'TotalPremium')

# Outlier Detection for 'TotalPremium'
print("\nOutlier Detection for 'TotalPremium':")
eda.outlier_detection('TotalPremium')
# Out:
# C:\Users/user/Desktop/Github/Insurance_solution/Scripts\Insurance_EDA.py:7: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(data_path, delimiter=delimiter)
# Data Summary:
#         UnderwrittenCoverID      PolicyID     TransactionMonth  \
# count          1.000098e+06  1.000098e+06              1000098
# unique                  NaN           NaN                   23
# top                     NaN           NaN  2015-08-01 00:00:00
# freq                    NaN           NaN               106747
# mean           1.048175e+05  7.956682e+03                  NaN
# std            6.329371e+04  5.290039e+03                  NaN
# min            1.000000e+00  1.400000e+01                  NaN
# 25%            5.514300e+04  4.500000e+03                  NaN
# 50%            9.408300e+04  7.071000e+03                  NaN
# 75%            1.391900e+05  1.107700e+04                  NaN
# ...
